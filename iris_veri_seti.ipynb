# %% [markdown]
# Irıs veri seti ile Uygulama

# %%
# add to library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
# Load data cvs
df=pd.read_csv('/content/drive/MyDrive/iris.csv')

# %%
# Data info and descriptive statistics
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
print(df)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#türlere göre ortalama alma
df.groupby('Species').mean()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %%
df.groupby('Species').sum()
# Out:
#                    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa      1275          250.3         170.9           73.2
# Iris-versicolor  3775          296.8         138.5          213.0
# Iris-virginica   6275          329.4         148.7          277.6
#
#                  PetalWidthCm
# Species
# Iris-setosa              12.2
# Iris-versicolor          66.3
# Iris-virginica          101.3

# %%
#df=df.drop('Id',axis=1) #id column dropped
df.groupby('Species').agg([min,max,np.std])
# Out:
#                   Id                SepalLengthCm                SepalWidthCm  \
#                  min  max       std           min  max       std          min
# Species
# Iris-setosa        1   50  14.57738           4.3  5.8  0.352490          2.3
# Iris-versicolor   51  100  14.57738           4.9  7.0  0.516171          2.0
# Iris-virginica   101  150  14.57738           4.9  7.9  0.635880          2.2
#
#                                PetalLengthCm                PetalWidthCm       \
#                  max       std           min  max       std          min  max
# Species
# Iris-setosa      4.4  0.381024           1.0  1.9  0.173511          0.1  0.6
# Iris-versicolor  3.4  0.313798           3.0  5.1  0.469911          1.0  1.8
# Iris-virginica   3.8  0.322497           4.5  6.9  0.551895          1.4  2.5
#
#
#                       std
# Species
# Iris-setosa      0.107210
# Iris-versicolor  0.197753
# Iris-virginica   0.274650

# %%
sns.scatterplot(x='SepalWidthCm',y='SepalLengthCm',hue="Species",data=df)
plt.title('Speal Width vs speal Length')
plt.show()

# %%
sns.scatterplot(x='PetalLengthCm',y='PetalWidthCm',hue="Species",data=df)
plt.title('pental Width vs pental Length')
plt.show()
